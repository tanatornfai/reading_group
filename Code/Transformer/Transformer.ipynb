# %% [markdown]
# ref: https://www.tensorflow.org/text/tutorials/transformer

# %% [markdown]
# # Set Up

# %%
# !pip install tensorflow_datasets
# !pip install -U tensorflow-text
# Out:
# Requirement already satisfied: tensorflow_datasets in /usr/local/lib/python3.7/dist-packages (4.0.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (3.17.3)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.12.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (5.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.15.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.3.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (4.62.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.1.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.19.5)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (1.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (0.16.0)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_datasets) (21.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow_datasets) (2.10)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->tensorflow_datasets) (3.5.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-metadata->tensorflow_datasets) (1.53.0)
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.6.0-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 7.7 MB/s
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text) (0.12.0)
# Requirement already satisfied: tensorflow<2.7,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text) (2.6.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.19.5)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.39.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (2.6.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.6.3)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (5.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (3.7.4.3)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.12.1)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (0.37.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (2.6.0)
# Requirement already satisfied: keras~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (3.17.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.1.2)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (0.4.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (0.12.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.1.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (1.12)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.7,>=2.6.0->tensorflow-text) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (0.4.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (57.4.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.34.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.8.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (4.6.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow<2.7,>=2.6.0->tensorflow-text) (3.5.0)
# Installing collected packages: tensorflow-text
# Successfully installed tensorflow-text-2.6.0

# %%
import collections
import logging
import os
import pathlib
import re
import string
import sys
import time

import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds
import tensorflow_text as text
import tensorflow as tf

# %% [markdown]
# # Data Preparation

# %%
examples, metadata = tfds.load('ted_hrlr_translate/pt_to_en', with_info=True,
                               as_supervised=True)
train_examples, val_examples = examples['train'], examples['validation']
# Out:
# Downloading and preparing dataset ted_hrlr_translate/pt_to_en/1.0.0 (download: 124.94 MiB, generated: Unknown size, total: 124.94 MiB) to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0.incompleteL1L6P5/ted_hrlr_translate-train.tfrecord
#   0%|          | 0/51785 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0.incompleteL1L6P5/ted_hrlr_translate-validation.tfrecord
#   0%|          | 0/1193 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0.incompleteL1L6P5/ted_hrlr_translate-test.tfrecord
#   0%|          | 0/1803 [00:00<?, ? examples/s]
# Dataset ted_hrlr_translate downloaded and prepared to /root/tensorflow_datasets/ted_hrlr_translate/pt_to_en/1.0.0. Subsequent calls will reuse this data.

# %%
model_name = "ted_hrlr_translate_pt_en_converter"
tf.keras.utils.get_file(
    f"{model_name}.zip",
    f"https://storage.googleapis.com/download.tensorflow.org/models/{model_name}.zip",
    cache_dir='.', cache_subdir='', extract=True
)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/models/ted_hrlr_translate_pt_en_converter.zip
# 188416/184801 [==============================] - 0s 0us/step
# 196608/184801 [===============================] - 0s 0us/step
# './ted_hrlr_translate_pt_en_converter.zip'

# %%
tokenizers = tf.saved_model.load(model_name)

# %%
def tokenize_pairs(pt, en):
    pt = tokenizers.pt.tokenize(pt)
    # Convert from ragged to dense, padding with zeros.
    pt = pt.to_tensor()

    en = tokenizers.en.tokenize(en)
    # Convert from ragged to dense, padding with zeros.
    en = en.to_tensor()
    return pt, en

# %%
BUFFER_SIZE = 20000
BATCH_SIZE = 64

# %%
def make_batches(ds):
  return (
      ds
      .cache()
      .shuffle(BUFFER_SIZE)
      .batch(BATCH_SIZE)
      .map(tokenize_pairs, num_parallel_calls=tf.data.AUTOTUNE)
      .prefetch(tf.data.AUTOTUNE))


train_batches = make_batches(train_examples)
val_batches = make_batches(val_examples)

# %% [markdown]
# # The Transformer Model

# %% [markdown]
# ## Low Level

# %% [markdown]
# ### Positional encoding
# ![image.png](data:image/png;base64,...)

# %%
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

  pos_encoding = angle_rads[np.newaxis, ...]

  return tf.cast(pos_encoding, dtype=tf.float32)

# %% [markdown]
# ### Mask

# %%
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)

  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask  # (seq_len, seq_len)

# %% [markdown]
# ### Scaled dot product attention

# %%
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead)
  but it must be broadcastable for addition.

  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable
          to (..., seq_len_q, seq_len_k). Defaults to None.

  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

# %% [markdown]
# ### Multi-head attention

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)

    self.dense = tf.keras.layers.Dense(d_model)

  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])

  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]

    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)

    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

    return output, attention_weights

# %% [markdown]
# ### Point wise feed forward network

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %% [markdown]
# ## Middle Level

# %% [markdown]
# ### Encoder layer

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()

    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)

    return out2

# %% [markdown]
# ### Decoder layer

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()

    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)

    self.ffn = point_wise_feed_forward_network(d_model, dff)

    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)

  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):
    # enc_output.shape == (batch_size, input_seq_len, d_model)

    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)

    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

    ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

    return out3, attn_weights_block1, attn_weights_block2

# %% [markdown]
# ## High Level

# %% [markdown]
# ### Encoder

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Encoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding,
                                            self.d_model)

    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]

    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, training, mask):

    seq_len = tf.shape(x)[1]

    # adding embedding and position encoding.
    x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)

    return x  # (batch_size, input_seq_len, d_model)

# %% [markdown]
# ### Decoder

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)

    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate)
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)

  def call(self, x, enc_output, training,
           look_ahead_mask, padding_mask):

    seq_len = tf.shape(x)[1]
    attention_weights = {}

    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]

    x = self.dropout(x, training=training)

    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)

      attention_weights[f'decoder_layer{i+1}_block1'] = block1
      attention_weights[f'decoder_layer{i+1}_block2'] = block2

    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %% [markdown]
# ### Transformer

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               target_vocab_size, pe_input, pe_target, rate=0.1):
    super().__init__()
    self.encoder = Encoder(num_layers, d_model, num_heads, dff,
                             input_vocab_size, pe_input, rate)

    self.decoder = Decoder(num_layers, d_model, num_heads, dff,
                           target_vocab_size, pe_target, rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)

  def call(self, inputs, training):
    # Keras models prefer if you pass all your inputs in the first argument
    inp, tar = inputs

    enc_padding_mask, look_ahead_mask, dec_padding_mask = self.create_masks(inp, tar)

    enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)

    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, dec_padding_mask)

    final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)

    return final_output, attention_weights

  def create_masks(self, inp, tar):
    # Encoder padding mask
    enc_padding_mask = create_padding_mask(inp)

    # Used in the 2nd attention block in the decoder.
    # This padding mask is used to mask the encoder outputs.
    dec_padding_mask = create_padding_mask(inp)

    # Used in the 1st attention block in the decoder.
    # It is used to pad and mask future tokens in the input received by
    # the decoder.
    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = create_padding_mask(tar)
    look_ahead_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return enc_padding_mask, look_ahead_mask, dec_padding_mask

# %% [markdown]
# # Training

# %% [markdown]
# ## Hyperparameters

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8
dropout_rate = 0.1

# %% [markdown]
# ## Optimizer
# Use the Adam optimizer with a custom learning rate scheduler according to the formula in the paper.

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                     epsilon=1e-9)

# %% [markdown]
# ## Loss and metrics

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)


def accuracy_function(real, pred):
  accuracies = tf.equal(real, tf.argmax(pred, axis=2))

  mask = tf.math.logical_not(tf.math.equal(real, 0))
  accuracies = tf.math.logical_and(mask, accuracies)

  accuracies = tf.cast(accuracies, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %% [markdown]
# ## Training and checkpointing

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=tokenizers.pt.get_vocab_size().numpy(),
    target_vocab_size=tokenizers.en.get_vocab_size().numpy(),
    pe_input=1000,
    pe_target=1000,
    rate=dropout_rate)

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
  ckpt.restore(ckpt_manager.latest_checkpoint)
  print('Latest checkpoint restored!!')

# %%
EPOCHS = 20

# %%
# The @tf.function trace-compiles train_step into a TF graph for faster
# execution. The function specializes to the precise shape of the argument
# tensors. To avoid re-tracing due to the variable sequence lengths or variable
# batch sizes (the last batch is smaller), use input_signature to specify
# more generic shapes.

train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]


@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]

  with tf.GradientTape() as tape:
    predictions, _ = transformer([inp, tar_inp],
                                 training = True)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

  train_loss(loss)
  train_accuracy(accuracy_function(tar_real, predictions))

# %%
for epoch in range(EPOCHS):
  start = time.time()

  train_loss.reset_states()
  train_accuracy.reset_states()

  # inp -> portuguese, tar -> english
  for (batch, (inp, tar)) in enumerate(train_batches):
    train_step(inp, tar)

    if batch % 50 == 0:
      print(f'Epoch {epoch + 1} Batch {batch} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print(f'Saving checkpoint for epoch {epoch+1} at {ckpt_save_path}')

  print(f'Epoch {epoch + 1} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

  print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
# Out:
# Epoch 1 Batch 0 Loss 8.8809 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 8.8105 Accuracy 0.0020
# Epoch 1 Batch 100 Loss 8.7164 Accuracy 0.0194
# Epoch 1 Batch 150 Loss 8.6045 Accuracy 0.0282
# Epoch 1 Batch 200 Loss 8.4638 Accuracy 0.0321
# Epoch 1 Batch 250 Loss 8.2936 Accuracy 0.0352
# Epoch 1 Batch 300 Loss 8.1033 Accuracy 0.0374
# Epoch 1 Batch 350 Loss 7.9061 Accuracy 0.0435
# Epoch 1 Batch 400 Loss 7.7167 Accuracy 0.0535
# Epoch 1 Batch 450 Loss 7.5473 Accuracy 0.0618
# Epoch 1 Batch 500 Loss 7.3992 Accuracy 0.0694
# Epoch 1 Batch 550 Loss 7.2647 Accuracy 0.0770
# Epoch 1 Batch 600 Loss 7.1382 Accuracy 0.0850
# Epoch 1 Batch 650 Loss 7.0221 Accuracy 0.0927
# Epoch 1 Batch 700 Loss 6.9151 Accuracy 0.0997
# Epoch 1 Batch 750 Loss 6.8147 Accuracy 0.1064
# Epoch 1 Batch 800 Loss 6.7228 Accuracy 0.1125
# Epoch 1 Loss 6.7059 Accuracy 0.1137
# Time taken for 1 epoch: 107.40 secs
#
# Epoch 2 Batch 0 Loss 5.3887 Accuracy 0.1876
# Epoch 2 Batch 50 Loss 5.2457 Accuracy 0.2124
# Epoch 2 Batch 100 Loss 5.2024 Accuracy 0.2180
# Epoch 2 Batch 150 Loss 5.1711 Accuracy 0.2211
# Epoch 2 Batch 200 Loss 5.1427 Accuracy 0.2235
# Epoch 2 Batch 250 Loss 5.1123 Accuracy 0.2268
# Epoch 2 Batch 300 Loss 5.0834 Accuracy 0.2297
# Epoch 2 Batch 350 Loss 5.0669 Accuracy 0.2310
# Epoch 2 Batch 400 Loss 5.0512 Accuracy 0.2326
# Epoch 2 Batch 450 Loss 5.0254 Accuracy 0.2350
# Epoch 2 Batch 500 Loss 5.0049 Accuracy 0.2370
# Epoch 2 Batch 550 Loss 4.9833 Accuracy 0.2389
# Epoch 2 Batch 600 Loss 4.9634 Accuracy 0.2405
# Epoch 2 Batch 650 Loss 4.9452 Accuracy 0.2420
# Epoch 2 Batch 700 Loss 4.9290 Accuracy 0.2433
# Epoch 2 Batch 750 Loss 4.9123 Accuracy 0.2448
# Epoch 2 Batch 800 Loss 4.8967 Accuracy 0.2460
# Epoch 2 Loss 4.8936 Accuracy 0.2463
# Time taken for 1 epoch: 93.11 secs
#
# Epoch 3 Batch 0 Loss 4.5365 Accuracy 0.2788
# Epoch 3 Batch 50 Loss 4.5963 Accuracy 0.2720
# Epoch 3 Batch 100 Loss 4.5826 Accuracy 0.2724
# Epoch 3 Batch 150 Loss 4.5772 Accuracy 0.2720
# Epoch 3 Batch 200 Loss 4.5646 Accuracy 0.2728
# Epoch 3 Batch 250 Loss 4.5533 Accuracy 0.2739
# Epoch 3 Batch 300 Loss 4.5395 Accuracy 0.2750
# Epoch 3 Batch 350 Loss 4.5335 Accuracy 0.2754
# Epoch 3 Batch 400 Loss 4.5189 Accuracy 0.2772
# Epoch 3 Batch 450 Loss 4.5018 Accuracy 0.2790
# Epoch 3 Batch 500 Loss 4.4845 Accuracy 0.2811
# Epoch 3 Batch 550 Loss 4.4702 Accuracy 0.2826
# Epoch 3 Batch 600 Loss 4.4561 Accuracy 0.2841
# Epoch 3 Batch 650 Loss 4.4420 Accuracy 0.2858
# Epoch 3 Batch 700 Loss 4.4262 Accuracy 0.2875
# Epoch 3 Batch 750 Loss 4.4104 Accuracy 0.2896
# Epoch 3 Batch 800 Loss 4.3935 Accuracy 0.2917
# Epoch 3 Loss 4.3910 Accuracy 0.2920
# Time taken for 1 epoch: 94.24 secs
#
# Epoch 4 Batch 0 Loss 3.8726 Accuracy 0.3562
# Epoch 4 Batch 50 Loss 4.0479 Accuracy 0.3311
# Epoch 4 Batch 100 Loss 4.0549 Accuracy 0.3298
# Epoch 4 Batch 150 Loss 4.0335 Accuracy 0.3316
# Epoch 4 Batch 200 Loss 4.0171 Accuracy 0.3341
# Epoch 4 Batch 250 Loss 4.0000 Accuracy 0.3364
# Epoch 4 Batch 300 Loss 3.9869 Accuracy 0.3388
# Epoch 4 Batch 350 Loss 3.9756 Accuracy 0.3405
# Epoch 4 Batch 400 Loss 3.9577 Accuracy 0.3429
# Epoch 4 Batch 450 Loss 3.9429 Accuracy 0.3451
# Epoch 4 Batch 500 Loss 3.9326 Accuracy 0.3465
# Epoch 4 Batch 550 Loss 3.9163 Accuracy 0.3487
# Epoch 4 Batch 600 Loss 3.9032 Accuracy 0.3505
# Epoch 4 Batch 650 Loss 3.8880 Accuracy 0.3527
# Epoch 4 Batch 700 Loss 3.8766 Accuracy 0.3542
# Epoch 4 Batch 750 Loss 3.8623 Accuracy 0.3561
# Epoch 4 Batch 800 Loss 3.8471 Accuracy 0.3583
# Epoch 4 Loss 3.8440 Accuracy 0.3587
# Time taken for 1 epoch: 94.14 secs
#
# Epoch 5 Batch 0 Loss 3.5126 Accuracy 0.3938
# Epoch 5 Batch 50 Loss 3.5569 Accuracy 0.3914
# Epoch 5 Batch 100 Loss 3.5490 Accuracy 0.3938
# Epoch 5 Batch 150 Loss 3.5203 Accuracy 0.3972
# Epoch 5 Batch 200 Loss 3.5002 Accuracy 0.4005
# Epoch 5 Batch 250 Loss 3.4916 Accuracy 0.4016
# Epoch 5 Batch 300 Loss 3.4775 Accuracy 0.4036
# Epoch 5 Batch 350 Loss 3.4688 Accuracy 0.4045
# Epoch 5 Batch 400 Loss 3.4579 Accuracy 0.4061
# Epoch 5 Batch 450 Loss 3.4493 Accuracy 0.4073
# Epoch 5 Batch 500 Loss 3.4445 Accuracy 0.4079
# Epoch 5 Batch 550 Loss 3.4327 Accuracy 0.4095
# Epoch 5 Batch 600 Loss 3.4212 Accuracy 0.4111
# Epoch 5 Batch 650 Loss 3.4119 Accuracy 0.4123
# Epoch 5 Batch 700 Loss 3.4037 Accuracy 0.4134
# Epoch 5 Batch 750 Loss 3.3955 Accuracy 0.4144
# Epoch 5 Batch 800 Loss 3.3863 Accuracy 0.4155
# Saving checkpoint for epoch 5 at ./checkpoints/train/ckpt-1
# Epoch 5 Loss 3.3844 Accuracy 0.4158
# Time taken for 1 epoch: 95.88 secs
#
# Epoch 6 Batch 0 Loss 3.2486 Accuracy 0.4400
# Epoch 6 Batch 50 Loss 3.1340 Accuracy 0.4419
# Epoch 6 Batch 100 Loss 3.1183 Accuracy 0.4441
# Epoch 6 Batch 150 Loss 3.1014 Accuracy 0.4462
# Epoch 6 Batch 200 Loss 3.0926 Accuracy 0.4477
# Epoch 6 Batch 250 Loss 3.0857 Accuracy 0.4488
# Epoch 6 Batch 300 Loss 3.0733 Accuracy 0.4506
# Epoch 6 Batch 350 Loss 3.0612 Accuracy 0.4529
# Epoch 6 Batch 400 Loss 3.0560 Accuracy 0.4537
# Epoch 6 Batch 450 Loss 3.0471 Accuracy 0.4552
# Epoch 6 Batch 500 Loss 3.0354 Accuracy 0.4572
# Epoch 6 Batch 550 Loss 3.0302 Accuracy 0.4581
# Epoch 6 Batch 600 Loss 3.0210 Accuracy 0.4593
# Epoch 6 Batch 650 Loss 3.0126 Accuracy 0.4608
# Epoch 6 Batch 700 Loss 3.0071 Accuracy 0.4615
# Epoch 6 Batch 750 Loss 2.9990 Accuracy 0.4627
# Epoch 6 Batch 800 Loss 2.9911 Accuracy 0.4638
# Epoch 6 Loss 2.9899 Accuracy 0.4641
# Time taken for 1 epoch: 94.24 secs
#
# Epoch 7 Batch 0 Loss 2.6269 Accuracy 0.5220
# Epoch 7 Batch 50 Loss 2.7441 Accuracy 0.4938
# Epoch 7 Batch 100 Loss 2.7185 Accuracy 0.4977
# Epoch 7 Batch 150 Loss 2.7154 Accuracy 0.4985
# Epoch 7 Batch 200 Loss 2.7048 Accuracy 0.5003
# Epoch 7 Batch 250 Loss 2.7031 Accuracy 0.5004
# Epoch 7 Batch 300 Loss 2.6972 Accuracy 0.5019
# Epoch 7 Batch 350 Loss 2.6911 Accuracy 0.5027
# Epoch 7 Batch 400 Loss 2.6823 Accuracy 0.5039
# Epoch 7 Batch 450 Loss 2.6768 Accuracy 0.5047
# Epoch 7 Batch 500 Loss 2.6722 Accuracy 0.5054
# Epoch 7 Batch 550 Loss 2.6665 Accuracy 0.5063
# Epoch 7 Batch 600 Loss 2.6610 Accuracy 0.5070
# Epoch 7 Batch 650 Loss 2.6571 Accuracy 0.5078
# Epoch 7 Batch 700 Loss 2.6541 Accuracy 0.5083
# Epoch 7 Batch 750 Loss 2.6494 Accuracy 0.5091
# Epoch 7 Batch 800 Loss 2.6466 Accuracy 0.5096
# Epoch 7 Loss 2.6463 Accuracy 0.5096
# Time taken for 1 epoch: 94.47 secs
#
# Epoch 8 Batch 0 Loss 2.3339 Accuracy 0.5477
# Epoch 8 Batch 50 Loss 2.4183 Accuracy 0.5375
# Epoch 8 Batch 100 Loss 2.4160 Accuracy 0.5381
# Epoch 8 Batch 150 Loss 2.4199 Accuracy 0.5385
# Epoch 8 Batch 200 Loss 2.4225 Accuracy 0.5383
# Epoch 8 Batch 250 Loss 2.4224 Accuracy 0.5386
# Epoch 8 Batch 300 Loss 2.4215 Accuracy 0.5388
# Epoch 8 Batch 350 Loss 2.4190 Accuracy 0.5391
# Epoch 8 Batch 400 Loss 2.4156 Accuracy 0.5399
# Epoch 8 Batch 450 Loss 2.4168 Accuracy 0.5395
# Epoch 8 Batch 500 Loss 2.4146 Accuracy 0.5400
# Epoch 8 Batch 550 Loss 2.4112 Accuracy 0.5404
# Epoch 8 Batch 600 Loss 2.4071 Accuracy 0.5411
# Epoch 8 Batch 650 Loss 2.4055 Accuracy 0.5414
# Epoch 8 Batch 700 Loss 2.4049 Accuracy 0.5415
# Epoch 8 Batch 750 Loss 2.4057 Accuracy 0.5416
# Epoch 8 Batch 800 Loss 2.4034 Accuracy 0.5419
# Epoch 8 Loss 2.4034 Accuracy 0.5419
# Time taken for 1 epoch: 94.77 secs
#
# Epoch 9 Batch 0 Loss 2.3722 Accuracy 0.5305
# Epoch 9 Batch 50 Loss 2.2372 Accuracy 0.5625
# Epoch 9 Batch 100 Loss 2.2194 Accuracy 0.5657
# Epoch 9 Batch 150 Loss 2.2286 Accuracy 0.5648
# Epoch 9 Batch 200 Loss 2.2307 Accuracy 0.5644
# Epoch 9 Batch 250 Loss 2.2301 Accuracy 0.5648
# Epoch 9 Batch 300 Loss 2.2293 Accuracy 0.5652
# Epoch 9 Batch 350 Loss 2.2272 Accuracy 0.5655
# Epoch 9 Batch 400 Loss 2.2275 Accuracy 0.5656
# Epoch 9 Batch 450 Loss 2.2278 Accuracy 0.5654
# Epoch 9 Batch 500 Loss 2.2252 Accuracy 0.5657
# Epoch 9 Batch 550 Loss 2.2253 Accuracy 0.5657
# Epoch 9 Batch 600 Loss 2.2275 Accuracy 0.5653
# Epoch 9 Batch 650 Loss 2.2244 Accuracy 0.5660
# Epoch 9 Batch 700 Loss 2.2237 Accuracy 0.5664
# Epoch 9 Batch 750 Loss 2.2240 Accuracy 0.5665
# Epoch 9 Batch 800 Loss 2.2247 Accuracy 0.5665
# Epoch 9 Loss 2.2245 Accuracy 0.5665
# Time taken for 1 epoch: 94.85 secs
#
# Epoch 10 Batch 0 Loss 2.2379 Accuracy 0.5560
# Epoch 10 Batch 50 Loss 2.0715 Accuracy 0.5850
# Epoch 10 Batch 100 Loss 2.0799 Accuracy 0.5848
# Epoch 10 Batch 150 Loss 2.0729 Accuracy 0.5861
# Epoch 10 Batch 200 Loss 2.0767 Accuracy 0.5860
# Epoch 10 Batch 250 Loss 2.0771 Accuracy 0.5860
# Epoch 10 Batch 300 Loss 2.0769 Accuracy 0.5860
# Epoch 10 Batch 350 Loss 2.0767 Accuracy 0.5861
# Epoch 10 Batch 400 Loss 2.0730 Accuracy 0.5869
# Epoch 10 Batch 450 Loss 2.0766 Accuracy 0.5863
# Epoch 10 Batch 500 Loss 2.0778 Accuracy 0.5862
# Epoch 10 Batch 550 Loss 2.0789 Accuracy 0.5863
# Epoch 10 Batch 600 Loss 2.0806 Accuracy 0.5862
# Epoch 10 Batch 650 Loss 2.0813 Accuracy 0.5863
# Epoch 10 Batch 700 Loss 2.0815 Accuracy 0.5864
# Epoch 10 Batch 750 Loss 2.0814 Accuracy 0.5864
# Epoch 10 Batch 800 Loss 2.0836 Accuracy 0.5862
# Saving checkpoint for epoch 10 at ./checkpoints/train/ckpt-2
# Epoch 10 Loss 2.0833 Accuracy 0.5862
# Time taken for 1 epoch: 95.01 secs
#
# Epoch 11 Batch 0 Loss 1.9749 Accuracy 0.5993
# Epoch 11 Batch 50 Loss 1.9331 Accuracy 0.6074
# Epoch 11 Batch 100 Loss 1.9469 Accuracy 0.6060
# Epoch 11 Batch 150 Loss 1.9518 Accuracy 0.6053
# Epoch 11 Batch 200 Loss 1.9478 Accuracy 0.6060
# Epoch 11 Batch 250 Loss 1.9525 Accuracy 0.6051
# Epoch 11 Batch 300 Loss 1.9560 Accuracy 0.6047
# Epoch 11 Batch 350 Loss 1.9600 Accuracy 0.6042
# Epoch 11 Batch 400 Loss 1.9583 Accuracy 0.6044
# Epoch 11 Batch 450 Loss 1.9603 Accuracy 0.6040
# Epoch 11 Batch 500 Loss 1.9634 Accuracy 0.6033
# Epoch 11 Batch 550 Loss 1.9636 Accuracy 0.6032
# Epoch 11 Batch 600 Loss 1.9638 Accuracy 0.6032
# Epoch 11 Batch 650 Loss 1.9663 Accuracy 0.6029
# Epoch 11 Batch 700 Loss 1.9683 Accuracy 0.6027
# Epoch 11 Batch 750 Loss 1.9696 Accuracy 0.6027
# Epoch 11 Batch 800 Loss 1.9716 Accuracy 0.6023
# Epoch 11 Loss 1.9722 Accuracy 0.6022
# Time taken for 1 epoch: 94.16 secs
#
# Epoch 12 Batch 0 Loss 1.8015 Accuracy 0.6319
# Epoch 12 Batch 50 Loss 1.8448 Accuracy 0.6195
# Epoch 12 Batch 100 Loss 1.8549 Accuracy 0.6178
# Epoch 12 Batch 150 Loss 1.8452 Accuracy 0.6189
# Epoch 12 Batch 200 Loss 1.8474 Accuracy 0.6186
# Epoch 12 Batch 250 Loss 1.8477 Accuracy 0.6186
# Epoch 12 Batch 300 Loss 1.8530 Accuracy 0.6177
# Epoch 12 Batch 350 Loss 1.8568 Accuracy 0.6174
# Epoch 12 Batch 400 Loss 1.8595 Accuracy 0.6172
# Epoch 12 Batch 450 Loss 1.8637 Accuracy 0.6167
# Epoch 12 Batch 500 Loss 1.8651 Accuracy 0.6167
# Epoch 12 Batch 550 Loss 1.8651 Accuracy 0.6169
# Epoch 12 Batch 600 Loss 1.8692 Accuracy 0.6164
# Epoch 12 Batch 650 Loss 1.8703 Accuracy 0.6163
# Epoch 12 Batch 700 Loss 1.8719 Accuracy 0.6162
# Epoch 12 Batch 750 Loss 1.8750 Accuracy 0.6157
# Epoch 12 Batch 800 Loss 1.8769 Accuracy 0.6154
# Epoch 12 Loss 1.8760 Accuracy 0.6155
# Time taken for 1 epoch: 94.57 secs
#
# Epoch 13 Batch 0 Loss 1.9341 Accuracy 0.6086
# Epoch 13 Batch 50 Loss 1.7474 Accuracy 0.6322
# Epoch 13 Batch 100 Loss 1.7691 Accuracy 0.6303
# Epoch 13 Batch 150 Loss 1.7713 Accuracy 0.6305
# Epoch 13 Batch 200 Loss 1.7743 Accuracy 0.6302
# Epoch 13 Batch 250 Loss 1.7739 Accuracy 0.6301
# Epoch 13 Batch 300 Loss 1.7766 Accuracy 0.6300
# Epoch 13 Batch 350 Loss 1.7791 Accuracy 0.6295
# Epoch 13 Batch 400 Loss 1.7808 Accuracy 0.6292
# Epoch 13 Batch 450 Loss 1.7826 Accuracy 0.6288
# Epoch 13 Batch 500 Loss 1.7841 Accuracy 0.6287
# Epoch 13 Batch 550 Loss 1.7854 Accuracy 0.6286
# Epoch 13 Batch 600 Loss 1.7882 Accuracy 0.6284
# Epoch 13 Batch 650 Loss 1.7910 Accuracy 0.6281
# Epoch 13 Batch 700 Loss 1.7914 Accuracy 0.6280
# Epoch 13 Batch 750 Loss 1.7950 Accuracy 0.6277
# Epoch 13 Batch 800 Loss 1.7966 Accuracy 0.6275
# Epoch 13 Loss 1.7963 Accuracy 0.6276
# Time taken for 1 epoch: 94.85 secs
#
# Epoch 14 Batch 0 Loss 1.7084 Accuracy 0.6494
# Epoch 14 Batch 50 Loss 1.6880 Accuracy 0.6426
# Epoch 14 Batch 100 Loss 1.6793 Accuracy 0.6445
# Epoch 14 Batch 150 Loss 1.6884 Accuracy 0.6437
# Epoch 14 Batch 200 Loss 1.6887 Accuracy 0.6435
# Epoch 14 Batch 250 Loss 1.6959 Accuracy 0.6424
# Epoch 14 Batch 300 Loss 1.7004 Accuracy 0.6416
# Epoch 14 Batch 350 Loss 1.7053 Accuracy 0.6410
# Epoch 14 Batch 400 Loss 1.7093 Accuracy 0.6405
# Epoch 14 Batch 450 Loss 1.7108 Accuracy 0.6402
# Epoch 14 Batch 500 Loss 1.7140 Accuracy 0.6396
# Epoch 14 Batch 550 Loss 1.7143 Accuracy 0.6399
# Epoch 14 Batch 600 Loss 1.7174 Accuracy 0.6395
# Epoch 14 Batch 650 Loss 1.7203 Accuracy 0.6392
# Epoch 14 Batch 700 Loss 1.7242 Accuracy 0.6385
# Epoch 14 Batch 750 Loss 1.7253 Accuracy 0.6384
# Epoch 14 Batch 800 Loss 1.7275 Accuracy 0.6381
# Epoch 14 Loss 1.7267 Accuracy 0.6382
# Time taken for 1 epoch: 94.69 secs
#
# Epoch 15 Batch 0 Loss 1.6404 Accuracy 0.6718
# Epoch 15 Batch 50 Loss 1.6110 Accuracy 0.6561
# Epoch 15 Batch 100 Loss 1.6122 Accuracy 0.6558
# Epoch 15 Batch 150 Loss 1.6122 Accuracy 0.6562
# Epoch 15 Batch 200 Loss 1.6248 Accuracy 0.6537
# Epoch 15 Batch 250 Loss 1.6328 Accuracy 0.6525
# Epoch 15 Batch 300 Loss 1.6378 Accuracy 0.6517
# Epoch 15 Batch 350 Loss 1.6418 Accuracy 0.6508
# Epoch 15 Batch 400 Loss 1.6466 Accuracy 0.6500
# Epoch 15 Batch 450 Loss 1.6505 Accuracy 0.6491
# Epoch 15 Batch 500 Loss 1.6518 Accuracy 0.6490
# Epoch 15 Batch 550 Loss 1.6528 Accuracy 0.6489
# Epoch 15 Batch 600 Loss 1.6540 Accuracy 0.6486
# Epoch 15 Batch 650 Loss 1.6589 Accuracy 0.6479
# Epoch 15 Batch 700 Loss 1.6608 Accuracy 0.6476
# Epoch 15 Batch 750 Loss 1.6617 Accuracy 0.6476
# Epoch 15 Batch 800 Loss 1.6646 Accuracy 0.6472
# Saving checkpoint for epoch 15 at ./checkpoints/train/ckpt-3
# Epoch 15 Loss 1.6657 Accuracy 0.6472
# Time taken for 1 epoch: 94.68 secs
#
# Epoch 16 Batch 0 Loss 1.5207 Accuracy 0.6683
# Epoch 16 Batch 50 Loss 1.5985 Accuracy 0.6543
# Epoch 16 Batch 100 Loss 1.5803 Accuracy 0.6589
# Epoch 16 Batch 150 Loss 1.5834 Accuracy 0.6581
# Epoch 16 Batch 200 Loss 1.5794 Accuracy 0.6590
# Epoch 16 Batch 250 Loss 1.5840 Accuracy 0.6585
# Epoch 16 Batch 300 Loss 1.5820 Accuracy 0.6590
# Epoch 16 Batch 350 Loss 1.5845 Accuracy 0.6585
# Epoch 16 Batch 400 Loss 1.5881 Accuracy 0.6583
# Epoch 16 Batch 450 Loss 1.5934 Accuracy 0.6573
# Epoch 16 Batch 500 Loss 1.5964 Accuracy 0.6569
# Epoch 16 Batch 550 Loss 1.5963 Accuracy 0.6571
# Epoch 16 Batch 600 Loss 1.5976 Accuracy 0.6570
# Epoch 16 Batch 650 Loss 1.6005 Accuracy 0.6567
# Epoch 16 Batch 700 Loss 1.6029 Accuracy 0.6564
# Epoch 16 Batch 750 Loss 1.6067 Accuracy 0.6559
# Epoch 16 Batch 800 Loss 1.6115 Accuracy 0.6552
# Epoch 16 Loss 1.6113 Accuracy 0.6553
# Time taken for 1 epoch: 94.63 secs
#
# Epoch 17 Batch 0 Loss 1.5793 Accuracy 0.6566
# Epoch 17 Batch 50 Loss 1.5343 Accuracy 0.6683
# Epoch 17 Batch 100 Loss 1.5313 Accuracy 0.6679
# Epoch 17 Batch 150 Loss 1.5323 Accuracy 0.6685
# Epoch 17 Batch 200 Loss 1.5375 Accuracy 0.6672
# Epoch 17 Batch 250 Loss 1.5379 Accuracy 0.6670
# Epoch 17 Batch 300 Loss 1.5394 Accuracy 0.6671
# Epoch 17 Batch 350 Loss 1.5398 Accuracy 0.6672
# Epoch 17 Batch 400 Loss 1.5419 Accuracy 0.6666
# Epoch 17 Batch 450 Loss 1.5467 Accuracy 0.6656
# Epoch 17 Batch 500 Loss 1.5485 Accuracy 0.6653
# Epoch 17 Batch 550 Loss 1.5491 Accuracy 0.6652
# Epoch 17 Batch 600 Loss 1.5505 Accuracy 0.6651
# Epoch 17 Batch 650 Loss 1.5542 Accuracy 0.6644
# Epoch 17 Batch 700 Loss 1.5575 Accuracy 0.6640
# Epoch 17 Batch 750 Loss 1.5592 Accuracy 0.6638
# Epoch 17 Batch 800 Loss 1.5626 Accuracy 0.6630
# Epoch 17 Loss 1.5630 Accuracy 0.6630
# Time taken for 1 epoch: 94.97 secs
#
# Epoch 18 Batch 0 Loss 1.4232 Accuracy 0.6954
# Epoch 18 Batch 50 Loss 1.4793 Accuracy 0.6759
# Epoch 18 Batch 100 Loss 1.4841 Accuracy 0.6750
# Epoch 18 Batch 150 Loss 1.4785 Accuracy 0.6769
# Epoch 18 Batch 200 Loss 1.4830 Accuracy 0.6761
# Epoch 18 Batch 250 Loss 1.4890 Accuracy 0.6748
# Epoch 18 Batch 300 Loss 1.4926 Accuracy 0.6737
# Epoch 18 Batch 350 Loss 1.4995 Accuracy 0.6725
# Epoch 18 Batch 400 Loss 1.4996 Accuracy 0.6725
# Epoch 18 Batch 450 Loss 1.5007 Accuracy 0.6721
# Epoch 18 Batch 500 Loss 1.5019 Accuracy 0.6720
# Epoch 18 Batch 550 Loss 1.5050 Accuracy 0.6716
# Epoch 18 Batch 600 Loss 1.5093 Accuracy 0.6709
# Epoch 18 Batch 650 Loss 1.5103 Accuracy 0.6708
# Epoch 18 Batch 700 Loss 1.5133 Accuracy 0.6705
# Epoch 18 Batch 750 Loss 1.5158 Accuracy 0.6702
# Epoch 18 Batch 800 Loss 1.5197 Accuracy 0.6695
# Epoch 18 Loss 1.5191 Accuracy 0.6696
# Time taken for 1 epoch: 94.29 secs
#
# Epoch 19 Batch 0 Loss 1.4056 Accuracy 0.6786
# Epoch 19 Batch 50 Loss 1.4539 Accuracy 0.6791
# Epoch 19 Batch 100 Loss 1.4446 Accuracy 0.6810
# Epoch 19 Batch 150 Loss 1.4439 Accuracy 0.6810
# Epoch 19 Batch 200 Loss 1.4440 Accuracy 0.6815
# Epoch 19 Batch 250 Loss 1.4492 Accuracy 0.6808
# Epoch 19 Batch 300 Loss 1.4497 Accuracy 0.6805
# Epoch 19 Batch 350 Loss 1.4520 Accuracy 0.6805
# Epoch 19 Batch 400 Loss 1.4567 Accuracy 0.6798
# Epoch 19 Batch 450 Loss 1.4592 Accuracy 0.6795
# Epoch 19 Batch 500 Loss 1.4589 Accuracy 0.6794
# Epoch 19 Batch 550 Loss 1.4623 Accuracy 0.6789
# Epoch 19 Batch 600 Loss 1.4651 Accuracy 0.6784
# Epoch 19 Batch 650 Loss 1.4672 Accuracy 0.6780
# Epoch 19 Batch 700 Loss 1.4717 Accuracy 0.6773
# Epoch 19 Batch 750 Loss 1.4749 Accuracy 0.6767
# Epoch 19 Batch 800 Loss 1.4788 Accuracy 0.6761
# Epoch 19 Loss 1.4803 Accuracy 0.6758
# Time taken for 1 epoch: 94.64 secs
#
# Epoch 20 Batch 0 Loss 1.3676 Accuracy 0.6981
# Epoch 20 Batch 50 Loss 1.4004 Accuracy 0.6877
# Epoch 20 Batch 100 Loss 1.3925 Accuracy 0.6894
# Epoch 20 Batch 150 Loss 1.3979 Accuracy 0.6880
# Epoch 20 Batch 200 Loss 1.4048 Accuracy 0.6868
# Epoch 20 Batch 250 Loss 1.4100 Accuracy 0.6862
# Epoch 20 Batch 300 Loss 1.4175 Accuracy 0.6850
# Epoch 20 Batch 350 Loss 1.4249 Accuracy 0.6835
# Epoch 20 Batch 400 Loss 1.4249 Accuracy 0.6837
# Epoch 20 Batch 450 Loss 1.4253 Accuracy 0.6835
# Epoch 20 Batch 500 Loss 1.4280 Accuracy 0.6831
# Epoch 20 Batch 550 Loss 1.4308 Accuracy 0.6829
# Epoch 20 Batch 600 Loss 1.4333 Accuracy 0.6825
# Epoch 20 Batch 650 Loss 1.4366 Accuracy 0.6820
# Epoch 20 Batch 700 Loss 1.4406 Accuracy 0.6815
# Epoch 20 Batch 750 Loss 1.4422 Accuracy 0.6812
# Epoch 20 Batch 800 Loss 1.4447 Accuracy 0.6808
# Saving checkpoint for epoch 20 at ./checkpoints/train/ckpt-4
# Epoch 20 Loss 1.4448 Accuracy 0.6808
# Time taken for 1 epoch: 94.50 secs
